# %% [markdown]
# # Correlation Between Ethnicity and Tightness of a Network

# %%
## Create the network using NLP in python

# %%
install.packages("igraph")
library("igraph")
# Out:
# Installing package into ‘/usr/local/spark-2.3.1-bin-hadoop2.7/R/lib’
# (as ‘lib’ is unspecified)
#
# Attaching package: ‘igraph’
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
## Load the csv file created using NLP from interview data

data <- as.matrix(read.csv("final_matrix.csv",row.names = 1))

# %%
attributes <- read.csv("updated_attributes_famiy.csv")

# %%
diag(data) <- NA

# %%
graphMatrix <- graph.adjacency(data, mode="undirected",
                            weighted=NULL, diag=FALSE)
graphMatrix
# Out:
# IGRAPH ea87f69 UN-- 114 235 --
# + attr: name (v/c)
# + edges from ea87f69 (vertex names):
#  [1] Allard         --Turcotte.Armand     Baillargon.Emma--Lebel.Fred
#  [3] Baillargon.Emma--Morin.John          Baillargon.Emma--Morin.Lilliane
#  [5] Baillargon.Emma--Morin.Rita          Barrett        --Lebel.Fred
#  [7] Belanger.Lucy  --Brackett.Ray        Belanger.Lucy  --Morhauser.Jeannette
#  [9] Belanger.Lucy  --Perreault.Norm      Bergeron.Gerard--Fournier.Real
# [11] Bergeron.Gerard--Morin.John          Bertrand.Roger --Berube.Norm
# [13] Bertrand.Roger --Harvey.Irene        Bertrand.Roger --Labbe.Doris
# [15] Bertrand.Roger --Labbe.Richard       Bertrand.Roger --Metayer.Ralph
# + ... omitted several edges

# %%
graphMatrixFamily <- graph.adjacency(data, mode="undirected",
                            weighted=NULL, diag=FALSE)
graphMatrixFamily
# Out:
# IGRAPH b8eaaaf UN-- 114 235 --
# + attr: name (v/c)
# + edges from b8eaaaf (vertex names):
#  [1] Allard         --Turcotte.Armand     Baillargon.Emma--Lebel.Fred
#  [3] Baillargon.Emma--Morin.John          Baillargon.Emma--Morin.Lilliane
#  [5] Baillargon.Emma--Morin.Rita          Barrett        --Lebel.Fred
#  [7] Belanger.Lucy  --Brackett.Ray        Belanger.Lucy  --Morhauser.Jeannette
#  [9] Belanger.Lucy  --Perreault.Norm      Bergeron.Gerard--Fournier.Real
# [11] Bergeron.Gerard--Morin.John          Bertrand.Roger --Berube.Norm
# [13] Bertrand.Roger --Harvey.Irene        Bertrand.Roger --Labbe.Doris
# [15] Bertrand.Roger --Labbe.Richard       Bertrand.Roger --Metayer.Ralph
# + ... omitted several edges

# %%
between <- betweenness(graphMatrix)
between
# Out:
#                  Allard         Baillargon.Emma                 Barrett
#               0.0000000               4.4166667               0.0000000
#                Beaulieu           Belanger.Lucy         Bergeron.Gerard
#               0.0000000              19.6094167              12.9904382
#          Bertrand.Roger            Berube.Henry            Berube.Irene
#             171.2125928              85.7789901              17.0986592
#             Berube.Norm              Berube.Ray            Bousquet.Ann
#             112.2674737              75.7635988               0.0000000
#            Brackett.Ray           Breton.Honore          Brown.Lorraine
#              84.2490007               0.0000000              32.0326799
#      Chamberlain.Dennis         Charest.Bernard     Charpentier.Dorothy
#               0.0000000              11.2878814               0.0000000
#           Cody.Valencia            Cote.Maurice       Courtemanche.Dick
#              90.0000000             165.3690616              18.9611402
#             Croteau.Ray             D.Amour.Ray            Daigle.Larry
#               0.1428571               1.6691198               0.0000000
#           Daigle.Vernon              Davis.Norm             Demers.Norm
#             297.6017585             173.3005421              90.0000000
# Desgrossielliers.Harvey    Desjardins.Constance            Drouin.Penny
#               7.5443875               0.0000000               0.0000000
#         Duchette.Conrad             Dutil.Betty            Farnum.Roger
#               7.5711685               0.0000000               0.0000000
#        Feinstein.Jerome       Fitzsimmons.Danny       Foisy.Aime.Aurore
#              78.5121824               4.5840909               0.0000000
#           Fournier.Real         Frechette.Emile            Gognon.Vital
#              73.6119520               0.0000000              16.2805309
#        Gervais.MaryJane           Giasson.Andre           Gilbert.Henry
#               0.0000000               0.0000000               0.0000000
#         Goranites.Maria          Gosselin.Jason         Gosselin.Roland
#               0.0000000             121.2254644             216.6601271
#             Gould.Ralph            Hanley.Bruce             Hanley.Neil
#               4.7164026             283.1600951               7.3273018
#            Harvey.Irene         Herrick.Charlie           Higgins.Nancy
#             112.2351528               0.0000000              90.0000000
#         Hynes.Laurianne            Jambard.Norm            Johanson.Ted
#               0.0000000              10.0002497               6.3214035
#                 Koss.Ed               Koss.Herb             Labbe.Doris
#             146.9645576              40.8938087              11.6427432
#           Labbe.Richard           LaChance.Eloi        LaChance.Everett
#              11.6427432               0.0000000               0.0000000
#            LaChance.Ron          Lafrance.Gerry       Lamontagne.Ernest
#               0.0000000              21.9782110               0.0000000
#           Landry.Roland              Lebel.Fred       Leblanc.Madeleine
#             244.8616867            1121.1504128             244.2489929
#         LeBlond.Richard         LeClair.Normand        Legendre.Blanche
#               0.0000000               0.0000000               9.5215007
#        Letourneau.Gerry              LeVeen.Tom            Levesque.Leo
#              92.1691198               0.0000000               0.0000000
#     Lewis.William..Bud.            Little.Helen            Madore.Irene
#              37.6650908             243.6298351              30.0462890
#              Mailey.Joe           Martel.Roland            Mathieu.Bert
#              95.6469520               0.0000000               0.0000000
#              McAtee.Dot           Metayer.Ralph     Morhauser.Jeannette
#               0.0000000               0.0000000              61.9307385
#              Morin.John          Morin.Lilliane              Morin.Rita
#             339.2197400             900.1164378             262.2410234
#            Morrell.Noel          Perreault.Norm        Poliquin.Charles
#               0.0000000             407.1324930               0.0000000
#            Poulin.Jerry              Pride.Dana             Quinn.David
#               0.4500000               3.7833333               0.0000000
#           Rancourt.Kyle           Rancourt.Mike            Ray.Jeannine
#              29.8559842              75.7612402               0.0000000
#          Ricker.Richard          Rivard.Laurent          Rousseau.Jerry
#              28.5443584               3.8333333              48.5697802
#            Roy.Jeannine         Shostak.Anthony              Smith.Lise
#            1170.9349271               0.0000000               0.0000000
#          St..Pierre.Ray         Tanguay.Normand           Tassinari.Roy
#               0.0000000               0.0000000              30.4114469
#           Tetrault.Jack            Thibault.Ray         Turcotte.Armand
#              14.0594888               0.0000000             354.7952855
#        Turcotte.Pauline            Vaillancourt          Vallee.Richard
#              26.9390306               4.4166667              23.9377511
#         Verreault.Roger        Vincent.Jean.Guy            Wellehan.Jim
#               0.0000000               0.0000000               0.0000000
#           Windle.Gordon              Wing.Monte           Young.Monique
#               0.0000000              31.7411770              60.7614336

# %%
eig_centrality <- evcent(graphMatrix)
eig_centrality
# Out:
# $vector
#                  Allard         Baillargon.Emma                 Barrett
#            3.326438e-02            2.926274e-01            3.016670e-02
#                Beaulieu           Belanger.Lucy         Bergeron.Gerard
#            2.898129e-02            3.236150e-02            1.985427e-02
#          Ricker.Richard          Rivard.Laurent          Rousseau.Jerry
#            8.924665e-02            4.568243e-02            1.353742e-02
#            Roy.Jeannine         Shostak.Anthony              Smith.Lise
#            2.054012e-01            6.845170e-03            1.158377e-18
#          St..Pierre.Ray         Tanguay.Normand           Tassinari.Roy
#            1.158377e-18            9.371070e-03            3.929566e-02
#           Tetrault.Jack            Thibault.Ray         Turcotte.Armand
#            2.715412e-01            1.397171e-02            3.441347e-01
#        Turcotte.Pauline            Vaillancourt          Vallee.Richard
#            8.609581e-02            2.926274e-01            2.689938e-01
#         Verreault.Roger        Vincent.Jean.Guy            Wellehan.Jim
#            2.146373e-03            1.158377e-18            1.158377e-18
#           Windle.Gordon              Wing.Monte           Young.Monique
#            1.730512e-02            2.686270e-01            2.426299e-02
#
# $value
# [1] 10.34544
#
# $options
# $options$bmat
# [1] "I"
#
# $options$n
# [1] 114
#
# $options$which
# [1] "LA"
#
# $options$nev
# [1] 1
#
# $options$tol
# [1] 0
#
# $options$ncv
# [1] 0
#
# $options$ldv
# [1] 0
#
# $options$ishift
# [1] 1
#
# $options$maxiter
# [1] 1000
#
# $options$nb
# [1] 1
#
# $options$mode
# [1] 1
#
# $options$start
# [1] 1
#
# $options$sigma
# [1] 0
#
# $options$sigmai
# [1] 0
#
# $options$info
# [1] 0
#
# $options$iter
# [1] 2
#
# $options$nconv
# [1] 1
#
# $options$numop
# [1] 30
#
# $options$numopb
# [1] 0
#
# $options$numreo
# [1] 21

# %%
V(graphMatrix)$country=as.character(attributes$birthplace_country[match(V(graphMatrix)$name,attributes$full)])

# %%
V(graphMatrix)$color <- V(graphMatrix)$country
V(graphMatrix)$color <- gsub("USA", 'red', V(graphMatrix)$color)
V(graphMatrix)$color <- gsub("Canada", 'blue', V(graphMatrix)$color)
V(graphMatrix)$color <- gsub("Greece", "green", V(graphMatrix)$color)

# %%
V(graphMatrixFamily)$country=as.character(attributes$parents_country[match(V(graphMatrixFamily)$name,attributes$full)])

# %%
V(graphMatrixFamily)$color <- V(graphMatrixFamily)$country
V(graphMatrixFamily)$color <- gsub("USA", 'red', V(graphMatrixFamily)$color)
V(graphMatrixFamily)$color <- gsub("Canada", 'blue', V(graphMatrixFamily)$color)
V(graphMatrixFamily)$color <- gsub("Greece", "green", V(graphMatrixFamily)$color)

# %%
png(file="national.png", width=1500, height=1500, res=300)
plot.igraph(graphMatrix, layout=layout.fruchterman.reingold, 
            edge.width = .25,
            vertex.size = 4,
            vertex.label=V(graphMatrix)$name, 
            vertex.label.cex = .25,
            asp = 0
            )
legend("topleft", 
       legend = c("USA", "Canada", "Greece"),
       xpd=TRUE,
       cex = 0.75,
       col = c("red", "blue", "green"),
       pch = 15)
dev.off()
# Out:
# png
#   2

# %%
png(file="familyCountry.png", width=1500, height=1500, res=300)
plot.igraph(graphMatrixFamily, layout=layout.fruchterman.reingold, 
            edge.width = .25,
            vertex.size = 4,
            vertex.label=V(graphMatrixFamily)$name, 
            vertex.label.cex = .25,
            asp = 0
            )
legend("topleft", 
       legend = c("USA", "Canada", "Greece"),
       xpd=TRUE,
       cex = 0.45,
       col = c("red", "blue", "green"),
       pch = 15)
dev.off()
# Out:
# png
#   2
